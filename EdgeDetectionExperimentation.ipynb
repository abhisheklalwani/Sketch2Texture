# %% [markdown]
# # Canny Edge Detection

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(16, 12), dpi=80)

img = cv.imread('Canny_Edge_Detection/Lenna.png',0)
edges = cv.Canny(img,100,200)
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(255 - edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# # DexiNed

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(16, 12), dpi=80)

img = cv.imread('Canny_Edge_Detection/Lenna.png',0)
edges_img = cv.imread('DexiNed/result/BIPED2CLASSIC/avg/lena_std.png',0)
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges_img,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### StyleGAN training pre-processing

# %%
import glob
import cv2

filenames = [img for img in glob.glob("C:/Users/Abhishek/Desktop/Texture Generation/Describable Textures Dataset/images/banded/*.jpg")]

filenames.sort() # ADD THIS LINE

images = []
for img in filenames:
    n = cv2.imread(img)
    cv2.imwrite(img,cv2.resize(n,(512,512)))
    print(img)
# Out:
# C:/Users/Abhishek/Desktop/Texture Generation/Describable Textures Dataset/images/banded\banded_0002.jpg
# C:/Users/Abhishek/Desktop/Texture Generation/Describable Textures Dataset/images/banded\banded_0004.jpg
# C:/Users/Abhishek/Desktop/Texture Generation/Describable Textures Dataset/images/banded\banded_0005.jpg
# C:/Users/Abhishek/Desktop/Texture Generation/Describable Textures Dataset/images/banded\banded_0006.jpg
# C:/Users/Abhishek/Desktop/Texture Generation/Describable Textures Dataset/images/banded\banded_0008.jpg
# C:/Users/Abhishek/Desktop/Texture Generation/Describable Textures Dataset/images/banded\banded_0009.jpg
# C:/Users/Abhishek/Desktop/Texture Generation/Describable Textures Dataset/images/banded\banded_0010.jpg
# C:/Users/Abhishek/Desktop/Texture Generation/Describable Textures Dataset/images/banded\banded_0011.jpg
# C:/Users/Abhishek/Desktop/Texture Generation/Describable Textures Dataset/images/banded\banded_0012.jpg
# ...
